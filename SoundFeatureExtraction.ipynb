# %%
import time
import numpy as np
import matplotlib.pyplot as plt
import librosa
import librosa.display

# %%
#load audio files

data, sr = librosa.load('/Users/shreyamitra/Downloads/Stairway_to_Heaven.mp3')
# Out:
# /Users/shreyamitra/opt/anaconda3/lib/python3.7/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")

# %%
print(data.shape)
# Out:
# (14347008,)

# %%
print(sr)
# Out:
# 22050

# %%
plt.plot(data)

# %%
data
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)

# %%
data.size
# Out:
# 14347008

# %%
#duration of 1 sample
sample_duration = 1/sr
print(f"Duration of 1 sample is : {sample_duration: 6f} seconds")
# Out:
# Duration of 1 sample is :  0.000045 seconds

# %%
#duration of the audio signal or the length of the audio file
duration = sample_duration * len(data)
print(f"Duration of signal is : {duration:.2f} seconds")
# Out:
# Duration of signal is : 650.66 seconds

# %%
#visualise the waveform
plt.figure(figsize=(15,17))
plt.plot(data)
